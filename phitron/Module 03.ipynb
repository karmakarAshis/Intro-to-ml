# %% [markdown]
# ## string

# %%
prompt = "What is your name?"

print(prompt)
# Out:
# What is your name?

# %%
message ="""
tell me about yourself
what are the issues you've been facing
"""

print(message)
# Out:
# tell me about yourself
# what are the issues you've been facing

# %% [markdown]
# ## indexing and slicing

# %%
string = "hello world"
print(string[6])   #string[satrt : end : step]
# Out:
# w

# %%
print(message[3:15:2])
# Out:
# l eaot

# %%
print(string[-1])
# Out:
# d

# %%
print(string[-1])
print(string[-2])
print(string[-3])
print(string[-4])
print(string[-5])
# Out:
# d
# l
# r
# o
# w

# %% [markdown]
# ## String Methods

# %%
print(len(message))
# Out:
# 63

# %%
print("hello" in string)
# Out:
# True

# %%
print("Hello" in string)
# Out:
# False

# %%
str2 = "Welcome to Jumanji, Game on Jumanji"

processed_str = str2.lower()

print(processed_str)

print("phitron" in processed_str)

shuru_index = processed_str.find("jumanji")
print(shuru_index)

sesh_index = processed_str.rfind("jumanji")
print(sesh_index)
# Out:
# welcome to jumanji, game on jumanji
# False
# 11
# 28
