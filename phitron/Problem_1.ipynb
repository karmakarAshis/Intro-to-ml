# %% [markdown]
# ## Problem : F: Digits summation

# %%
numbers = input().split()

num1 = int(numbers[0])
num2 = int(numbers[1])

last_digit_x = num1%10
last_digit_y = num2%10

sum = last_digit_x+last_digit_y

print(sum)
# Out:
# 5
