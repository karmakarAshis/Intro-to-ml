# %% [markdown]
# ## Tuple

# %%
tup = (10, 20, 30, 40, 50)

print(tup)
# Out:
# (10, 20, 30, 40, 50)

# %%
mixed_tup = ("ashis", 15, 18, True )
print(mixed_tup)
# Out:
# ('ashis', 15, 18, True)

# %%
lst = [10, 20, 30, 40, 50]

lst.append(60)

print(lst)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
tup2 = tuple(lst)
tup2
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(tup2.count(10))
# Out:
# 1

# %%
print(tup2.index(40))
# Out:
# 3

# %% [markdown]
# ## Set

# %%
# unique elements
# mutable
# unordered 
#      x-indexing x
#      x-sllicing x

# %%
a={1, 2, 3, 5, 6, 7 ,7}
a
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
type(a)
# Out:
# set

# %%
sum=0
for item in a:
    sum+=item

print(sum)
# Out:
# 24

# %%
## Set mathemetical methods

# %%
a = {1, 2, 3}
b = {2, 3, 4}

a.union(b)
# Out:
# {1, 2, 3, 4}

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
a = {1, 2, 3}
b = {5, 6, 4}

a.isdisjoint(b)
# Out:
# True

# %% [markdown]
# ## Dictionaries

# %%
dic={}
print(type(dic))

dic = {"name":"phitron", "age": 25, "address": "Dhaka", "number": [10, 20, 30, 50]}
print(dic)
# Out:
# <class 'dict'>
# {'name': 'phitron', 'age': 25, 'address': 'Dhaka', 'number': [10, 20, 30, 50]}

# %%
#access
# dic_name[key]

print(dic["number"])
print(dic.get("age"))

dic["name"] = "Phitron AI/ML"


print(dic)
# Out:
# [10, 20, 30, 50]
# 25
# {'name': 'Phitron AI/ML', 'age': 25, 'address': 'Dhaka', 'number': [10, 20, 30, 50]}
