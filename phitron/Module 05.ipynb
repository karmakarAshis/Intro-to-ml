# %% [markdown]
# ## Tuple

# %%
tup = (10, 20, 30, 40, 50)

print(tup)
# Out:
# (10, 20, 30, 40, 50)

# %%
mixed_tup = ("ashis", 15, 18, True )
print(mixed_tup)
# Out:
# ('ashis', 15, 18, True)

# %%
lst = [10, 20, 30, 40, 50]

lst.append(60)

print(lst)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
tup2 = tuple(lst)
tup2
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(tup2.count(10))
# Out:
# 1

# %%
print(tup2.index(40))
# Out:
# 3

# %% [markdown]
# ## Set

# %%
# unique elements
# mutable
# unordered 
#      x-indexing x
#      x-sllicing x

# %%
a={1, 2, 3, 5, 6, 7 ,7}
a
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
type(a)
# Out:
# set

# %%
sum=0
for item in a:
    sum+=item

print(sum)
# Out:
# 24

# %%
## Set mathemetical methods

# %%
a = {1, 2, 3}
b = {2, 3, 4}

a.union(b)
# Out:
# {1, 2, 3, 4}

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
a = {1, 2, 3}
b = {5, 6, 4}

a.isdisjoint(b)
# Out:
# True

# %% [markdown]
# ## Dictionaries

# %%
dic={}
print(type(dic))

dic = {"name":"phitron", "age": 25, "address": "Dhaka", "number": [10, 20, 30, 50]}
print(dic)
# Out:
# <class 'dict'>
# {'name': 'phitron', 'age': 25, 'address': 'Dhaka', 'number': [10, 20, 30, 50]}

# %%
#access
# dic_name[key]

print(dic["number"])
print(dic.get("age"))

dic["name"] = "Phitron AI/ML"


print(dic)
# Out:
# [10, 20, 30, 50]
# 25
# {'name': 'Phitron AI/ML', 'age': 25, 'address': 'Dhaka', 'number': [10, 20, 30, 50]}

# %% [markdown]
# ## Dictionary methods

# %%
dic
# Out:
# {'name': 'Phitron AI/ML',
#  'age': 25,
#  'address': 'Dhaka',
#  'number': [10, 20, 30, 50]}

# %%
print(dic.get("math_marks", 0))
# Out:
# 0

# %%
dic["math_marks"] = 30

# %%
dic
# Out:
# {'name': 'Phitron AI/ML',
#  'age': 25,
#  'address': 'Dhaka',
#  'number': [10, 20, 30, 50],
#  'math_marks': 30}

# %%
del dic["math_marks"]

# %%
dic
# Out:
# {'name': 'Phitron AI/ML',
#  'age': 25,
#  'address': 'Dhaka',
#  'number': [10, 20, 30, 50]}

# %%
dic2 = dic.copy()
print(dic2)
# Out:
# {'name': 'Phitron AI/ML', 'age': 25, 'address': 'Dhaka', 'number': [10, 20, 30, 50]}

# %%
square = {x:x**2 for x in range(1,11) if x%2==0}
print(square)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %%
cor_ordinate = [(10,10.5), (20.5, 192), (101,102)]
location = ["Dhaka", "Chattogram", "sylhet"]

extract_loc = {co_or : loc for co_or, loc in zip(cor_ordinate, location)}

# %%
extract_loc
# Out:
# {(10, 10.5): 'Dhaka', (20.5, 192): 'Chattogram', (101, 102): 'sylhet'}

# %%
print(words)
# Out:
# ['Lorem', 'ipsum', 'dolor,', 'sit', 'amet', 'consectetur', 'adipisicing', 'elit.', 'Unde', 'alias', 'nobis', 'dignissimos', 'asperiores', 'nulla', 'tempora,', 'inventore', 'at', 'ipsam.', 'Quod', 'officia', 'cum', 'error', 'sapiente', 'eos', 'vitae', 'atque', 'rerum', 'nostrum,', 'voluptates', 'maiores', 'pariatur,', 'non', 'culpa', 'qui', 'laboriosam', 'ipsam,', 'excepturi', 'laudantium', 'ab?', 'Temporibus', 'facere', 'soluta', 'cupiditate', 'vel', 'assumenda', 'libero', 'eius', 'possimus', 'obcaecati', 'esse?', 'Lorem', 'ipsum', 'dolor,', 'sit', 'amet', 'consectetur', 'adipisicing', 'elit.', 'Unde', 'alias', 'nobis', 'dignissimos', 'asperiores', 'nulla', 'tempora,', 'inventore', 'at', 'ipsam.', 'Quod', 'officia', 'cum', 'error', 'sapiente', 'eos', 'vitae', 'atque', 'rerum', 'nostrum,', 'voluptates', 'maiores', 'pariatur,', 'non', 'culpa', 'qui', 'laboriosam', 'ipsam,', 'excepturi', 'laudantium', 'ab?', 'Temporibus', 'facere', 'soluta', 'cupiditate', 'Lorem', 'ipsum', 'dolor,', 'si
# ...

# %%
count.get("Lorem")
# Out:
# 3

# %%
text = "Lorem ipsum dolor, sit amet consectetur adipisicing elit. Unde alias nobis dignissimos asperiores nulla tempora, inventore at ipsam. Quod officia cum error sapiente eos vitae atque rerum nostrum, voluptates maiores pariatur, non culpa qui laboriosam ipsam, excepturi laudantium ab? Temporibus facere soluta cupiditate vel assumenda libero eius possimus obcaecati esse? Lorem ipsum dolor, sit amet consectetur adipisicing elit. Unde alias nobis dignissimos asperiores nulla tempora, inventore at ipsam. Quod officia cum error sapiente eos vitae atque rerum nostrum, voluptates maiores pariatur, non culpa qui laboriosam ipsam, excepturi laudantium ab? Temporibus facere soluta cupiditate Lorem ipsum dolor, sit amet consectetur adipisicing elit. Unde alias nobis dignissimos asperiores nulla tempora, inventore at ipsam. Quod officia cum error sapiente eos vitae atque rerum nostrum, voluptates maiores pariatur, non culpa qui laboriosam ipsam, excepturi laudantium ab? Temporibus facere soluta cupiditate vel assumenda libero eius possimus obcaecatiLorem ipsum dolor, sit amet consectetur adipisicing elit. Unde alias nobis dignissimos asperiores nulla tempora, inventore at ipsam. Quod officia cum error sapiente eos vitae atque rerum nostrum, voluptates maiores pariatur, non culpa qui laboriosam ipsam, excepturi laudantium ab? Temporibus facere soluta cupiditate vel assumenda libero eius possimus obcaecatiLorem ipsum dolor, sit amet consectetur adipisicing elit. Unde alias nobis dignissimos asperiores nulla tempora, inventore at ipsam. Quod officia cum error sapiente eos vitae atque rerum nostrum, voluptates maiores pariatur, non culpa qui laboriosam ipsam, excepturi laudantium ab? Temporibus facere soluta cupiditate vel assumenda libero eius possimus obcaecatiLorem ipsum dolor, sit amet consectetur adipisicing elit. Unde alias nobis dignissimos asperiores nulla tempora, inventore at ipsam. Quod officia cum error sapiente eos vitae atque rerum nostrum, voluptates maiores pariatur, non culpa qui laboriosam ipsam, excepturi laudantium ab? Temporibus facere soluta cupiditate vel assumenda libero eius possimus obcaecatiLorem ipsum dolor, sit amet consectetur adipisicing elit. Unde alias nobis dignissimos asperiores nulla tempora, inventore at ipsam. Quod officia cum error sapiente eos vitae atque rerum nostrum, voluptates maiores pariatur, non culpa qui laboriosam ipsam, excepturi laudantium ab? Temporibus facere soluta cupiditate vel assumenda libero eius possimus obcaecatiLorem ipsum dolor, sit amet consectetur adipisicing elit. Unde alias nobis dignissimos asperiores nulla tempora, inventore at ipsam. Quod officia cum error sapiente eos vitae atque rerum nostrum, voluptates maiores pariatur, non culpa qui laboriosam ipsam, excepturi laudantium ab? Temporibus facere soluta cupiditate vel assumenda libero eius possimus obcaecatiLorem ipsum dolor, sit amet consectetur adipisicing elit. Unde alias nobis dignissimos asperiores nulla tempora, inventore at ipsam. Quod officia cum error sapiente eos vitae atque rerum nostrum, voluptates maiores pariatur, non culpa qui laboriosam ipsam, excepturi laudantium ab? Temporibus facere soluta cupiditate vel assumenda libero eius possimus obcaecativel assumenda libero eius possimus obcaecati"

words = text.split()

count = {}

for word in words:
    count[word] = count.get(word, 0) +1

print(count)
# Out:
# {'Lorem': 3, 'ipsum': 9, 'dolor,': 9, 'sit': 9, 'amet': 9, 'consectetur': 9, 'adipisicing': 9, 'elit.': 9, 'Unde': 9, 'alias': 9, 'nobis': 9, 'dignissimos': 9, 'asperiores': 9, 'nulla': 9, 'tempora,': 9, 'inventore': 9, 'at': 9, 'ipsam.': 9, 'Quod': 9, 'officia': 9, 'cum': 9, 'error': 9, 'sapiente': 9, 'eos': 9, 'vitae': 9, 'atque': 9, 'rerum': 9, 'nostrum,': 9, 'voluptates': 9, 'maiores': 9, 'pariatur,': 9, 'non': 9, 'culpa': 9, 'qui': 9, 'laboriosam': 9, 'ipsam,': 9, 'excepturi': 9, 'laudantium': 9, 'ab?': 9, 'Temporibus': 9, 'facere': 9, 'soluta': 9, 'cupiditate': 9, 'vel': 8, 'assumenda': 9, 'libero': 9, 'eius': 9, 'possimus': 9, 'obcaecati': 2, 'esse?': 1, 'obcaecatiLorem': 6, 'obcaecativel': 1}
