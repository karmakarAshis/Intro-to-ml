# %%
"""sdkjhkdjsh"""
# Out:
# 'sdkjhkdjsh'

# %%
name = "ashis"
print(name)
# Out:
# ashis

# %%
name = 4
name
# Out:
# 4

# %%
# Dynamic binding python
# static binding c, c++

# %%
a, b, c = 4, 5, 6
a, b, c
# Out:
# (4, 5, 6)
