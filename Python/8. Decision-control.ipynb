# %%
# correct mail : learnpython@gmail.com
# password : 12234

email = input("Enter email: ")
password = input("Enter password: ")

if email == "learnpython@gmail.com" and password == "12234":
    print("welcome")
elif email == "learnpython@gmail.com" and password != "12234":
    print("wrong Password")
    password = input("Enter correct password: ")
    if password == "12234":
        print("Finaly correct")
    else:
        print("still incorrect")
else:
    print("incorrect credential")
# Out:
# Enter email:  klo
# Enter password:  ji
# incorrect credential
