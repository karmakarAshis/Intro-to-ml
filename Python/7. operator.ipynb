# %% [markdown]
# # Operator
# * Arithmetic
# * comperison
# * logical
# * bitwise
# * assignment
# * identity
# * membership

# %%
x =2
y =5

# %%
x+y
# Out:
# 7

# %%
x-y
# Out:
# -3

# %%
x*y
# Out:
# 10

# %%
x/y
# Out:
# 0.4

# %%
x**y
# Out:
# 32

# %%
y//x
# Out:
# 2

# %%
x>y
# Out:
# False

# %%
x>=y
# Out:
# False

# %%
x<y
# Out:
# True
