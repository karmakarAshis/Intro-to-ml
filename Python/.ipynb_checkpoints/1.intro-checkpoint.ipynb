# %%
print("hello world")
# Out:
# hello world

# %%
print(5)
# Out:
# 5

# %%
print(4.2)
# Out:
# 4.2

# %%
print(False)
# Out:
# False

# %%
print("Bangladesh", "india", "nepal")
# Out:
# Bangladesh india nepal

# %%
print("BD", 5, 3.14, True, sep="/")
# Out:
# BD/5/3.14/True

# %%
print("hello", end=' ')
print("world")
# Out:
# hello world

# %%
message = "hello python crash course"
message
# Out:
# 'hello python crash course'

# %%
message = "hi py"

# %% [markdown]
# message

# %%
message
# Out:
# 'hi py'

# %%
name = "ada lovelace"

print(name.title())
# Out:
# Ada Lovelace

# %%
name.upper()
# Out:
# 'ADA LOVELACE'

# %%
name.lower()
# Out:
# 'ada lovelace'

# %%
first = "ada"
last = "lovelace"

# %%
full_name =f"{first} {last}"
full_name
# Out:
# 'ada lovelace'

# %%
print(f"Hello, {full_name.title()}")
# Out:
# Hello, Ada Lovelace

# %%
full = "{} {}".format(first, last)
full.title()
# Out:
# 'Ada Lovelace'

# %%
lang = "python     "
lang
# Out:
# 'python     '

# %%
lang.rstrip()
# Out:
# 'python'

# %%
lang1 = "          py      "

# %%
lang1
# Out:
# '          py      '

# %%
lang1.strip()
# Out:
# 'py'

# %%
lang2 = "    python"
lang2
# Out:
# '    python'

# %%
lang2.lstrip()
# Out:
# 'python'

# %%
2+3
# Out:
# 5

# %%
3-2
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
3/2
# Out:
# 1.5

# %%
3**2
# Out:
# 9

# %%
3**3
# Out:
# 27

# %%
10**6
# Out:
# 1000000

# %%
2+3*4
# Out:
# 14

# %%
(2+3)*4
# Out:
# 20

# %%
0.1+0.1
# Out:
# 0.2

# %%
2*0.2
# Out:
# 0.4

# %%
0.2+0.1
# Out:
# 0.30000000000000004

# %%
3*0.1
# Out:
# 0.30000000000000004

# %%
0.3+0.1
# Out:
# 0.4

# %%
4//2
# Out:
# 2

# %%
3//2
# Out:
# 1

# %%
universal_age = 14_000_000_000

# %%
universal_age
# Out:
# 14000000000

# %%
x, y, z = 0,1,2

# %%
z*y
# Out:
# 2

# %%
MAX_VALUE = 500

# %%
MAX_VALUE
# Out:
# 500
