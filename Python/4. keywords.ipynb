# %% [markdown]
# # keywords
#
# * python is a case sensitive programing language

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Identifiers
# * a python indentifier is a name used to identifu var,  func, module, other object
#
# # rule of naming indentifier
#
# * can only start with an alphabet or _
# * follow by 0 or more letter
# * keyword cannot be used as an iden

# %%
_ba = "Ashis"
